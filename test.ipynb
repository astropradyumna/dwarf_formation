# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from errani_plus_tng_subhalo import Subhalo 
from tqdm import tqdm
import illustris_python as il 
from joblib import Parallel, delayed
import sys
import os
sys.path.append(os.path.abspath('/bigdata/saleslab/psadh003/tng50-dark-analysis'))
from hydro_path_for_files import * 
from constant import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 from errani_plus_tng_subhalo import Subhalo
#       5 from tqdm import tqdm
#       6 import illustris_python as il
#
# ModuleNotFoundError: No module named 'errani_plus_tng_subhalo'
